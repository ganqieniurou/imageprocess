# %%
import numpy as np
from PIL import Image
import matplotlib.pyplot as plt
import math
# %matplotlib inline

img = Image.open('D:\JupyterFile\Lenna.png')

# %%
# Gaussian Filter
def Gaussian_filter(k,sigma):
    ksize = k * 2 + 1
    kernel = np.zeros([ksize,ksize])
    for i in range(ksize):
        for j in range(ksize):
            kernel[i,j] = math.exp(-((i-k)**2+(j-k)**2)/(2*sigma**2))
    return kernel

# Laplacian of the Gaussian(LoG) filter
def LoG_filter(k,sigma):
    ksize = k * 2 + 1
    kernel = np.zeros([ksize,ksize])
    for x in range(ksize):
        for y in range(ksize):
            i = x - k
            j = y - k
            kernel[x,y] = math.exp(-(i**2+j**2)/(2*sigma**2))*((i**2+j**2-2*sigma**2)/sigma**4)
    return kernel

# Difference of Gaussian(DoG) filter
def DoG_filter(k,sigma1,sigma2):
    return Gaussian_filter(k,sigma1)/sigma1 - Gaussian_filter(k,sigma2)/sigma2

# %%
#reference
#Digital image processing(4th edition) p522

def marr_edgedetec(img,k=1,sigma=1):
    gray = img.convert('L')
    gray = np.array(gray,dtype = np.int32)
    
    Gfilter = Gaussian_filter(k,sigma)
    laplace_filter = np.array([[-1,-1,-1],[-1, 8,-1],[-1,-1,-1],])

#Gaussian filter
    bb = np.pad(gray,k,'edge')
    ksize = 2 * k + 1
    sumt = np.sum(Gfilter)
    for i in range(img.size[1]):
        for j in range(img.size[0]):
            gray[i,j] = int(np.sum(bb[i:i + ksize,j:j + ksize] * Gfilter)/sumt)
    
#Laplace operator
    bb = np.pad(gray,1,'edge')
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            gray[i,j] += np.sum(bb[i:i + 3,j:j + 3] * laplace_filter)
    
#Clossing zero
    bb = np.pad(gray,1,'edge')
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            if bb[i,j]*bb[i + 2,j + 2] < 0 or bb[i + 1,j]*bb[i + 1,j + 2] < 0 or bb[i,j + 1]*bb[i + 2,j + 1] < 0 or bb[i + 2,j]*bb[i,j + 2] < 0:
                gray[i,j] = 255
            else:
                gray[i,j] = 0
    
    return Image.fromarray(np.uint8(gray))

# %%
#reference
#http://fourier.eng.hmc.edu/e161/lectures/gradient/node8.html
#Digital image processing(4th edition) p521

def LoG_edgedetec(img,k=4,sigma=1.6):
    gray = img.convert('L')
    gray = np.array(gray,dtype = np.int32)
    
    LoGfilter = LoG_filter(k,sigma)
    
# Laplacian of the Gaussian(LoG) filter
    bb = np.pad(gray,k,'edge')
    ksize = 2 * k + 1
    sumt = np.sum(LoGfilter)
    for i in range(img.size[1]):
        for j in range(img.size[0]):
            gray[i,j] = int(np.sum(bb[i:i + ksize,j:j + ksize] * LoGfilter)/sumt)

#Threshold    
    thre = np.int32(0.04 * np.max(gray))
    gray = gray + thre
    
#Clossing zero    
    bb = np.pad(gray,1,'edge')
    for i in range(img.size[0]):
        for j in range(img.size[1]):
            if bb[i,j]*bb[i + 2,j + 2] < 0 or bb[i + 1,j]*bb[i + 1,j + 2] < 0 or bb[i,j + 1]*bb[i + 2,j + 1] < 0 or bb[i + 2,j]*bb[i,j + 2] < 0:
                gray[i,j] = 255
            else:
                gray[i,j] = 0    
    
    return Image.fromarray(np.uint8(gray))

# %%
#reference
#http://fourier.eng.hmc.edu/e161/lectures/gradient/node9.html
#Digital image processing(4th edition) p523

def DoG_edgedetec(img,k=1,sigma1=0.3,sigma2=0.55):
    gray = img.convert('L')
    gray = np.array(gray,dtype = np.float64)
    
    DoGfilter = DoG_filter(k,sigma1,sigma2)
    
# Difference of Gaussian(DoG) filter
    bb = np.pad(gray,k,'edge')
    ksize = 2 * k + 1
    sumt = np.sum(DoGfilter)
    for i in range(img.size[1]):
        for j in range(img.size[0]):
            gray[i,j] = int(np.sum(bb[i:i + ksize,j:j + ksize] * DoGfilter)/sumt)

#Threshold    
    thre = np.int32(0.04 * np.max(gray))
    gray = gray + thre
    
#Clossing zero    
    bb = np.pad(gray,1,'edge')
    for i in range(img.size[1]):
        for j in range(img.size[0]):
            if bb[i,j]*bb[i + 2,j + 2] < 0 or bb[i + 1,j]*bb[i + 1,j + 2] < 0 or bb[i,j + 1]*bb[i + 2,j + 1] < 0 or bb[i + 2,j]*bb[i,j + 2] < 0:
                gray[i,j] = 255
            else:
                gray[i,j] = 0    

    return Image.fromarray(np.uint8(gray))

# %%
plt.subplot(141),plt.imshow(marr_edgedetec(img),'gray')
plt.subplot(142),plt.imshow(LoG_edgedetec(img),'gray')
plt.subplot(143),plt.imshow(DoG_edgedetec(img),'gray')
plt.subplot(144),plt.imshow(img.convert('L'),'gray')
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x194e0d0d610>,
#  <matplotlib.image.AxesImage at 0x194e0d6b4c0>)

# %%
img.close()
